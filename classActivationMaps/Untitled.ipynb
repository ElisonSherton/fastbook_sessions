# %% [markdown]
# # Class Activation Maps

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from grad_cam import *

# %%
path = untar_data(URLs.PETS)/'images'
def is_cat(x): return ["Cat" if x[0].isupper() else "Dog"][0]
dls = ImageDataLoaders.from_name_func(
                                path, get_image_files(path), valid_pct=0.2, seed=21,
                                label_func=is_cat, item_tfms=Resize(224), bs = 16)
learn = cnn_learner(dls, resnet18, metrics=accuracy)
learn.fine_tune(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.192167</td>
#       <td>0.051384</td>
#       <td>0.981732</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.133469</td>
#       <td>0.041861</td>
#       <td>0.985115</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.055095</td>
#       <td>0.019310</td>
#       <td>0.993234</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036590</td>
#       <td>0.007821</td>
#       <td>0.997970</td>
#       <td>00:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
create_grad_cam_visualization(learn, 'images/chapter1_cat_example.jpg')
