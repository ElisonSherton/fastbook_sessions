# %%
from fastai import *
from fastai.vision import *

import warnings
warnings.filterwarnings('ignore')

# %%
path = untar_data(URLs.MNIST_SAMPLE)

# %%
path.ls()
# Out:
# [PosixPath('/home/vinayak/.fastai/data/mnist_sample/train'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/labels.csv'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/valid')]

# %%
(path/"train"/"3").ls()
# Out:
# [PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/4033.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/1035.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/29045.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/26593.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/2228.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/36018.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/46005.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/8880.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/14527.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/4512.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/48849.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/2503.png'),
#  PosixPath('/home/vinayak/.fastai/data/mnist_sample/train/3/24868.png'),
# ...
