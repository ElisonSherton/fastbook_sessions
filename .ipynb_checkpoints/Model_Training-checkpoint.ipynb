# %%
from fastai import *
from fastai.vision.all import *

import warnings
warnings.filterwarnings('ignore')

# %%
# Specify where to load the data from
path = Path("/home/vinayak/Avengers")

# %%
# Define the template to load the data
avengers = DataBlock(
                      # Specify the kind of inputs and the kind of outputs
                      blocks=(ImageBlock, CategoryBlock), 
                      # Specify how to get the input
                      get_items=get_image_files, 
                      # Specify how to perform the train and validation splits
                      splitter=RandomSplitter(valid_pct=0.2, seed=42),
                      # Specify how to read the dependent label
                      get_y=parent_label,
                      # Before going on gpu, any transforms to be done should be specified here
                      item_tfms=Resize(256)
                     )

# %%
# Create dataloader for loading in the data
dls = avengers.dataloaders(path, bs = 16)

# %%
# Have a look at a sample of validation data
# By default center crops the image
# https://docs.fast.ai/vision.augment.html#Resize
dls.train.show_batch(max_n=5, nrows=1)

# %%
# Augment the data to include transformations for increasing dataset
avengers = avengers.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = avengers.dataloaders(path)
dls.train.show_batch(max_n=5, nrows=1, unique = True)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(8, freeze_epochs = 3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.920329</td>
#       <td>2.334128</td>
#       <td>0.710000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.596701</td>
#       <td>1.639580</td>
#       <td>0.620000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.195640</td>
#       <td>1.413959</td>
#       <td>0.520000</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.359086</td>
#       <td>1.572051</td>
#       <td>0.590000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.253602</td>
#       <td>1.473231</td>
#       <td>0.540000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.199566</td>
#       <td>1.316048</td>
#       <td>0.500000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.111434</td>
#       <td>1.290681</td>
#       <td>0.500000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.050619</td>
#       <td>1.362589</td>
#       <td>0.490000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.985338</td>
#       <td>1.313905</td>
#       <td>0.440000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.920663</td>
#       <td>1.302837</td>
#       <td>0.460000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.869596</td>
#       <td>1.309093</td>
#       <td>0.450000</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(6, nrows=2, ncols = 3)

# %% [markdown]
# ## Export Model

# %%
learn.export()
